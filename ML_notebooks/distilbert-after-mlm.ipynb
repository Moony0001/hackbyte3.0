# %%
from transformers import AutoModelForSequenceClassification, AutoTokenizer, Trainer, TrainingArguments,EarlyStoppingCallback
import pandas as pd
from datasets import Dataset
import torch
import numpy as np
from safetensors.torch import load_file

# %%
df=pd.read_csv("/kaggle/input/isec-sdc-2025/train.csv")
test_df=pd.read_csv("/kaggle/input/isec-sdc-2025/test.csv")

# %%
# df,test_df=df[:1000],test_df[:100]

# %%
df["Description"]=df["Description"].fillna("Not provided")
test_df["Description"]=test_df["Description"].fillna("Not provided")

# %%
from sklearn.model_selection import train_test_split
train_df, val_df = train_test_split(df, test_size=0.25, random_state=7,stratify=df['Priority'])

# %%
print(train_df.shape)
print(val_df.shape)
print(test_df.shape)
# Out:
# (39745, 7)
# (13249, 7)
# (1328, 6)

# %%
from sklearn.utils.class_weight import compute_class_weight

class_weights = compute_class_weight(class_weight='balanced', classes=np.unique(df["Priority"]), y=df["Priority"])

print(class_weights)
# Out:
# [1.1851504  1.12609435 0.34020672 4.63436817 8.84707846]

# %%
tokenizer = AutoTokenizer.from_pretrained("distilbert-base-cased")
model = AutoModelForSequenceClassification.from_pretrained('distilbert-base-cased', num_labels=5,output_hidden_states=True,trust_remote_code=True)
from safetensors.torch import load_file
state_dict = load_file("/kaggle/input/bert-mlm/saved_model/model.safetensors")

# Load the state into the model
model.load_state_dict(state_dict,strict=False)
# Out:
# tokenizer_config.json:   0%|          | 0.00/49.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/465 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/213k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/436k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/263M [00:00<?, ?B/s]
# Some weights of DistilBertForSequenceClassification were not initialized from the model checkpoint at distilbert-base-cased and are newly initialized: ['classifier.bias', 'classifier.weight', 'pre_classifier.bias', 'pre_classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# _IncompatibleKeys(missing_keys=['pre_classifier.weight', 'pre_classifier.bias', 'classifier.weight', 'classifier.bias'], unexpected_keys=['vocab_layer_norm.bias', 'vocab_layer_norm.weight', 'vocab_projector.bias', 'vocab_transform.bias', 'vocab_transform.weight'])

# %%
def filter_data(df,components, titles, descriptions,max_length=512):
    df["combined_texts"] = [f"{component} [SEP] {title} [SEP] {description}" 
                      for component, title, description in zip(components, titles, descriptions)]
    df['token_count'] = df['combined_texts'].apply(lambda x: len(tokenizer.encode(str(x), add_special_tokens=True)))
    
    # Keep only rows with <= 512 tokens
    df_filtered = df[df['token_count'] <= 512].copy()
    df_filtered = df_filtered.drop('combined_texts', axis=1)
    return df_filtered
    
    # return inputs
train_df=filter_data(train_df,train_df["Component"],train_df["Title"],train_df["Description"])
# Out:
# Token indices sequence length is longer than the specified maximum sequence length for this model (1589 > 512). Running this sequence through the model will result in indexing errors

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)  # Move model to device
class_weights_tensor = torch.tensor(class_weights, dtype=torch.float32).to(device)

# %%
def tokenize_data(components, titles, descriptions,max_length=512):
    combined_texts = [f"{component} [SEP] {title} [SEP] {description}" 
                      for component, title, description in zip(components, titles, descriptions)]
    
    # Tokenize the combined texts
    inputs = tokenizer(combined_texts, padding="longest", truncation=True, return_tensors="pt", max_length=max_length)
    
    return inputs

# %%
def create_dataset(inputs,labels):
    data = Dataset.from_dict({
            'input_ids': inputs['input_ids'],
            'attention_mask': inputs['attention_mask'],
            'labels': labels
        })
    return data

# %%
train_inputs=tokenize_data(train_df["Component"],train_df["Title"],train_df["Description"])
val_inputs=tokenize_data(val_df["Component"],val_df["Title"],val_df["Description"])
test_inputs=tokenize_data(test_df["Component"],test_df["Title"],test_df["Description"])

# %%
train_data=create_dataset(train_inputs,train_df["Priority"])
val_data=create_dataset(val_inputs,val_df["Priority"])

# %%
class WeightedTrainer(Trainer):
    def compute_loss(self, model, inputs, return_outputs=False, num_items_in_batch=None):
        # print(inputs)  # Debugging: Check input structure

        labels = inputs.pop("labels")  # Extract labels
        outputs = model(**inputs)  
        logits = outputs.logits  # Extract raw logits (not loss!)

        # Compute per-sample loss
        loss_fct = torch.nn.CrossEntropyLoss(reduction="none")  # Keep per-sample loss
        loss = loss_fct(logits, labels)  # Loss is now a tensor

        # Fetch sample weights based on labels
        sample_weights = class_weights_tensor[labels]  
        # print("Sample Weights:", sample_weights)  # Debugging

        # Apply sample weights to per-sample loss
        weighted_loss = (loss * sample_weights).mean()  # Scalar loss

        return (weighted_loss, outputs) if return_outputs else weighted_loss

# %%
def fine_tune_model(train_data,val_data,epochs=3):
    from transformers import DataCollatorWithPadding
    data_collator = DataCollatorWithPadding(tokenizer=tokenizer)
    training_args = TrainingArguments(
        output_dir='./results',
        overwrite_output_dir=True,
        logging_dir='./logs',
        logging_strategy="steps",
        logging_steps=1000,
        warmup_steps=600,
        eval_steps=1000,
        save_steps=1000,
        num_train_epochs=epochs,
        per_device_eval_batch_size=64,
        per_device_train_batch_size=8,
        # gradient_accumulation_steps=2,  # Gradient accumulation step size
        seed=7,
        fp16=True,
        report_to=[],
        optim="adafactor",
        weight_decay=0.01,
        eval_strategy="steps", 
        save_strategy="steps",
        load_best_model_at_end=True,
        save_total_limit=2,
        disable_tqdm=True,
        # learning_rate=2e-05
    )

    # Initialize Trainer
    trainer = WeightedTrainer(
        model=model,
        args=training_args,
        train_dataset=train_data,
        eval_dataset=val_data,
        callbacks = [EarlyStoppingCallback(early_stopping_patience=1)],
        data_collator=data_collator,
    )

    # Train the model
    trainer.train()

# %%
fine_tune_model(train_data,val_data)
# Out:
# {'loss': 1.5975, 'grad_norm': 815598.1875, 'learning_rate': 4.6725605762933864e-05, 'epoch': 0.4472271914132379}
# {'eval_loss': 1.5295149087905884, 'eval_runtime': 113.5198, 'eval_samples_per_second': 116.711, 'eval_steps_per_second': 0.916, 'epoch': 0.4472271914132379}
# {'loss': 1.4622, 'grad_norm': 330091.21875, 'learning_rate': 3.8539620170268504e-05, 'epoch': 0.8944543828264758}
# {'eval_loss': 1.521209478378296, 'eval_runtime': 113.5129, 'eval_samples_per_second': 116.718, 'eval_steps_per_second': 0.916, 'epoch': 0.8944543828264758}
# {'loss': 1.3967, 'grad_norm': 714534.3125, 'learning_rate': 3.0353634577603147e-05, 'epoch': 1.341681574239714}
# {'eval_loss': 1.4055826663970947, 'eval_runtime': 113.5663, 'eval_samples_per_second': 116.663, 'eval_steps_per_second': 0.916, 'epoch': 1.341681574239714}
# {'loss': 1.3113, 'grad_norm': 400739.78125, 'learning_rate': 2.2167648984937787e-05, 'epoch': 1.7889087656529516}
# {'eval_loss': 1.4973418712615967, 'eval_runtime': 113.5459, 'eval_samples_per_second': 116.684, 'eval_steps_per_second': 0.916, 'epoch': 1.7889087656529516}
# {'train_runtime': 2244.3683, 'train_samples_per_second': 47.809, 'train_steps_per_second': 2.989, 'train_loss': 1.441919921875, 'epoch': 1.7889087656529516}

# %%
len(train_data)
# Out:
# 35767

# %%
def get_embeddings(inputs,batch_size=64):
    model.eval()
    all_embeddings=[]
    input_ids = inputs['input_ids']
    attention_mask = inputs['attention_mask']

    with torch.no_grad():  # Disable gradient calculation
        for i in range(0, len(input_ids), batch_size):
            print(f"Processing batch {i // batch_size + 1}/{(len(input_ids) // batch_size) + 1}")

            # Slice batch inputs
            batch_input_ids = input_ids[i:i+batch_size].to(model.device)  # Ensure input is on the correct device
            batch_attention_mask = attention_mask[i:i+batch_size].to(model.device)

            # Run inference
            outputs = model(input_ids=batch_input_ids, attention_mask=batch_attention_mask, output_hidden_states=True)
            hidden_states = outputs.hidden_states

            # Extract embeddings for CLS token
            cls_embeddings = hidden_states[-1][:, 0, :].cpu().numpy()  # Move to CPU and convert to numpy
            all_embeddings.extend(cls_embeddings)

    # Convert list of embeddings to DataFrame
    embeddings_df = pd.DataFrame(all_embeddings)
    return embeddings_df

# %%
train_embedded=get_embeddings(train_inputs)
val_embedded=get_embeddings(val_inputs)
test_embedded=get_embeddings(test_inputs)
# Out:
# Processing batch 1/559
# Processing batch 2/559
# Processing batch 3/559
# Processing batch 4/559
# Processing batch 5/559
# Processing batch 6/559
# Processing batch 7/559
# Processing batch 8/559
# Processing batch 9/559
# Processing batch 10/559
# Processing batch 11/559
# Processing batch 12/559
# Processing batch 13/559
# Processing batch 14/559
# Processing batch 15/559
# Processing batch 16/559
# Processing batch 17/559
# Processing batch 18/559
# Processing batch 19/559
# Processing batch 20/559
# Processing batch 21/559
# Processing batch 22/559
# Processing batch 23/559
# Processing batch 24/559
# Processing batch 25/559
# Processing batch 26/559
# Processing batch 27/559
# Processing batch 28/559
# Processing batch 29/559
# Processing batch 30/559
# Processing batch 31/559
# Processing batch 32/559
# Processing batch 33/559
# Processing batch 34/559
# Processing batch 35/559
# Processing batch 36/559
# Processing batch 37/559
# Processing batch 38/559
# Processing batch 39/559
# Processing batch 40/559
# Processing batch 41/559
# Processing batch 42/559
# Processing batch 43/559
# Processing batch 44/559
# Processing batch 45/559
# Processing batch 46/559
# Processing batch 47/559
# Processing batch 48/559
# Processing batch 49/559
# Processing batch 50/559
# Processing batch 51/559
# Processing batch 52/559
# Processing batch 53/559
# Processing batch 54/559
# Processing batch 55/559
# Processing batch 56/559
# Processing batch 57/559
# Processing batch 58/559
# Processing batch 59/559
# Processing batch 60/559
# Processing batch 61/559
# Processing batch 62/559
# Processing batch 63/559
# Processing batch 64/559
# Processing batch 65/559
# Processing batch 66/559
# Processing batch 67/559
# Processing batch 68/559
# Processing batch 69/559
# Processing batch 70/559
# Processing batch 71/559
# Processing batch 72/559
# Processing batch 73/559
# Processing batch 74/559
# Processing batch 75/559
# Processing batch 76/559
# Processing batch 77/559
# Processing batch 78/559
# Processing batch 79/559
# Processing batch 80/559
# Processing batch 81/559
# Processing batch 82/559
# Processing batch 83/559
# Processing batch 84/559
# Processing batch 85/559
# Processing batch 86/559
# Processing batch 87/559
# Processing batch 88/559
# Processing batch 89/559
# Processing batch 90/559
# Processing batch 91/559
# Processing batch 92/559
# Processing batch 93/559
# Processing batch 94/559
# Processing batch 95/559
# Processing batch 96/559
# Processing batch 97/559
# Processing batch 98/559
# Processing batch 99/559
# Processing batch 100/559
# Processing batch 101/559
# Processing batch 102/559
# Processing batch 103/559
# Processing batch 104/559
# Processing batch 105/559
# Processing batch 106/559
# Processing batch 107/559
# Processing batch 108/559
# Processing batch 109/559
# Processing batch 110/559
# Processing batch 111/559
# Processing batch 112/559
# Processing batch 113/559
# Processing batch 114/559
# Processing batch 115/559
# Processing batch 116/559
# Processing batch 117/559
# Processing batch 118/559
# Processing batch 119/559
# Processing batch 120/559
# Processing batch 121/559
# Processing batch 122/559
# Processing batch 123/559
# Processing batch 124/559
# Processing batch 125/559
# Processing batch 126/559
# Processing batch 127/559
# Processing batch 128/559
# Processing batch 129/559
# Processing batch 130/559
# Processing batch 131/559
# Processing batch 132/559
# Processing batch 133/559
# Processing batch 134/559
# Processing batch 135/559
# Processing batch 136/559
# Processing batch 137/559
# Processing batch 138/559
# Processing batch 139/559
# Processing batch 140/559
# Processing batch 141/559
# Processing batch 142/559
# Processing batch 143/559
# Processing batch 144/559
# Processing batch 145/559
# Processing batch 146/559
# Processing batch 147/559
# Processing batch 148/559
# Processing batch 149/559
# Processing batch 150/559
# Processing batch 151/559
# Processing batch 152/559
# Processing batch 153/559
# Processing batch 154/559
# Processing batch 155/559
# Processing batch 156/559
# Processing batch 157/559
# Processing batch 158/559
# Processing batch 159/559
# Processing batch 160/559
# Processing batch 161/559
# Processing batch 162/559
# Processing batch 163/559
# Processing batch 164/559
# Processing batch 165/559
# Processing batch 166/559
# Processing batch 167/559
# Processing batch 168/559
# Processing batch 169/559
# Processing batch 170/559
# Processing batch 171/559
# Processing batch 172/559
# Processing batch 173/559
# Processing batch 174/559
# Processing batch 175/559
# Processing batch 176/559
# Processing batch 177/559
# Processing batch 178/559
# Processing batch 179/559
# Processing batch 180/559
# Processing batch 181/559
# Processing batch 182/559
# Processing batch 183/559
# Processing batch 184/559
# Processing batch 185/559
# Processing batch 186/559
# Processing batch 187/559
# Processing batch 188/559
# Processing batch 189/559
# Processing batch 190/559
# Processing batch 191/559
# Processing batch 192/559
# Processing batch 193/559
# Processing batch 194/559
# Processing batch 195/559
# Processing batch 196/559
# Processing batch 197/559
# Processing batch 198/559
# Processing batch 199/559
# Processing batch 200/559
# Processing batch 201/559
# Processing batch 202/559
# Processing batch 203/559
# Processing batch 204/559
# Processing batch 205/559
# Processing batch 206/559
# Processing batch 207/559
# Processing batch 208/559
# Processing batch 209/559
# Processing batch 210/559
# Processing batch 211/559
# Processing batch 212/559
# Processing batch 213/559
# Processing batch 214/559
# Processing batch 215/559
# Processing batch 216/559
# Processing batch 217/559
# Processing batch 218/559
# Processing batch 219/559
# Processing batch 220/559
# Processing batch 221/559
# Processing batch 222/559
# Processing batch 223/559
# Processing batch 224/559
# Processing batch 225/559
# Processing batch 226/559
# Processing batch 227/559
# Processing batch 228/559
# Processing batch 229/559
# Processing batch 230/559
# Processing batch 231/559
# Processing batch 232/559
# Processing batch 233/559
# Processing batch 234/559
# Processing batch 235/559
# Processing batch 236/559
# Processing batch 237/559
# Processing batch 238/559
# Processing batch 239/559
# Processing batch 240/559
# Processing batch 241/559
# Processing batch 242/559
# Processing batch 243/559
# Processing batch 244/559
# Processing batch 245/559
# Processing batch 246/559
# Processing batch 247/559
# Processing batch 248/559
# Processing batch 249/559
# Processing batch 250/559
# Processing batch 251/559
# Processing batch 252/559
# Processing batch 253/559
# Processing batch 254/559
# Processing batch 255/559
# Processing batch 256/559
# Processing batch 257/559
# Processing batch 258/559
# Processing batch 259/559
# Processing batch 260/559
# Processing batch 261/559
# Processing batch 262/559
# Processing batch 263/559
# Processing batch 264/559
# Processing batch 265/559
# Processing batch 266/559
# Processing batch 267/559
# Processing batch 268/559
# Processing batch 269/559
# Processing batch 270/559
# Processing batch 271/559
# Processing batch 272/559
# Processing batch 273/559
# Processing batch 274/559
# Processing batch 275/559
# Processing batch 276/559
# Processing batch 277/559
# Processing batch 278/559
# Processing batch 279/559
# Processing batch 280/559
# Processing batch 281/559
# Processing batch 282/559
# Processing batch 283/559
# Processing batch 284/559
# Processing batch 285/559
# Processing batch 286/559
# Processing batch 287/559
# Processing batch 288/559
# Processing batch 289/559
# Processing batch 290/559
# Processing batch 291/559
# Processing batch 292/559
# Processing batch 293/559
# Processing batch 294/559
# Processing batch 295/559
# Processing batch 296/559
# Processing batch 297/559
# Processing batch 298/559
# Processing batch 299/559
# Processing batch 300/559
# Processing batch 301/559
# Processing batch 302/559
# Processing batch 303/559
# Processing batch 304/559
# Processing batch 305/559
# Processing batch 306/559
# Processing batch 307/559
# Processing batch 308/559
# Processing batch 309/559
# Processing batch 310/559
# Processing batch 311/559
# Processing batch 312/559
# Processing batch 313/559
# Processing batch 314/559
# Processing batch 315/559
# Processing batch 316/559
# Processing batch 317/559
# Processing batch 318/559
# Processing batch 319/559
# Processing batch 320/559
# Processing batch 321/559
# Processing batch 322/559
# Processing batch 323/559
# Processing batch 324/559
# Processing batch 325/559
# Processing batch 326/559
# Processing batch 327/559
# Processing batch 328/559
# Processing batch 329/559
# Processing batch 330/559
# Processing batch 331/559
# Processing batch 332/559
# Processing batch 333/559
# Processing batch 334/559
# Processing batch 335/559
# Processing batch 336/559
# Processing batch 337/559
# Processing batch 338/559
# Processing batch 339/559
# Processing batch 340/559
# Processing batch 341/559
# Processing batch 342/559
# Processing batch 343/559
# Processing batch 344/559
# Processing batch 345/559
# Processing batch 346/559
# Processing batch 347/559
# Processing batch 348/559
# Processing batch 349/559
# Processing batch 350/559
# Processing batch 351/559
# Processing batch 352/559
# Processing batch 353/559
# Processing batch 354/559
# Processing batch 355/559
# Processing batch 356/559
# Processing batch 357/559
# Processing batch 358/559
# Processing batch 359/559
# Processing batch 360/559
# Processing batch 361/559
# Processing batch 362/559
# Processing batch 363/559
# Processing batch 364/559
# Processing batch 365/559
# Processing batch 366/559
# Processing batch 367/559
# Processing batch 368/559
# Processing batch 369/559
# Processing batch 370/559
# Processing batch 371/559
# Processing batch 372/559
# Processing batch 373/559
# Processing batch 374/559
# Processing batch 375/559
# Processing batch 376/559
# Processing batch 377/559
# Processing batch 378/559
# Processing batch 379/559
# Processing batch 380/559
# Processing batch 381/559
# Processing batch 382/559
# Processing batch 383/559
# Processing batch 384/559
# Processing batch 385/559
# Processing batch 386/559
# Processing batch 387/559
# Processing batch 388/559
# Processing batch 389/559
# Processing batch 390/559
# Processing batch 391/559
# Processing batch 392/559
# Processing batch 393/559
# Processing batch 394/559
# Processing batch 395/559
# Processing batch 396/559
# Processing batch 397/559
# Processing batch 398/559
# Processing batch 399/559
# Processing batch 400/559
# Processing batch 401/559
# Processing batch 402/559
# Processing batch 403/559
# Processing batch 404/559
# Processing batch 405/559
# Processing batch 406/559
# Processing batch 407/559
# Processing batch 408/559
# Processing batch 409/559
# Processing batch 410/559
# Processing batch 411/559
# Processing batch 412/559
# Processing batch 413/559
# Processing batch 414/559
# Processing batch 415/559
# Processing batch 416/559
# Processing batch 417/559
# Processing batch 418/559
# Processing batch 419/559
# Processing batch 420/559
# Processing batch 421/559
# Processing batch 422/559
# Processing batch 423/559
# Processing batch 424/559
# Processing batch 425/559
# Processing batch 426/559
# Processing batch 427/559
# Processing batch 428/559
# Processing batch 429/559
# Processing batch 430/559
# Processing batch 431/559
# Processing batch 432/559
# Processing batch 433/559
# Processing batch 434/559
# Processing batch 435/559
# Processing batch 436/559
# Processing batch 437/559
# Processing batch 438/559
# Processing batch 439/559
# Processing batch 440/559
# Processing batch 441/559
# Processing batch 442/559
# Processing batch 443/559
# Processing batch 444/559
# Processing batch 445/559
# Processing batch 446/559
# Processing batch 447/559
# Processing batch 448/559
# Processing batch 449/559
# Processing batch 450/559
# Processing batch 451/559
# Processing batch 452/559
# Processing batch 453/559
# Processing batch 454/559
# Processing batch 455/559
# Processing batch 456/559
# Processing batch 457/559
# Processing batch 458/559
# Processing batch 459/559
# Processing batch 460/559
# Processing batch 461/559
# Processing batch 462/559
# Processing batch 463/559
# Processing batch 464/559
# Processing batch 465/559
# Processing batch 466/559
# Processing batch 467/559
# Processing batch 468/559
# Processing batch 469/559
# Processing batch 470/559
# Processing batch 471/559
# Processing batch 472/559
# Processing batch 473/559
# Processing batch 474/559
# Processing batch 475/559
# Processing batch 476/559
# Processing batch 477/559
# Processing batch 478/559
# Processing batch 479/559
# Processing batch 480/559
# Processing batch 481/559
# Processing batch 482/559
# Processing batch 483/559
# Processing batch 484/559
# Processing batch 485/559
# Processing batch 486/559
# Processing batch 487/559
# Processing batch 488/559
# Processing batch 489/559
# Processing batch 490/559
# Processing batch 491/559
# Processing batch 492/559
# Processing batch 493/559
# Processing batch 494/559
# Processing batch 495/559
# Processing batch 496/559
# Processing batch 497/559
# Processing batch 498/559
# Processing batch 499/559
# Processing batch 500/559
# Processing batch 501/559
# Processing batch 502/559
# Processing batch 503/559
# Processing batch 504/559
# Processing batch 505/559
# Processing batch 506/559
# Processing batch 507/559
# Processing batch 508/559
# Processing batch 509/559
# Processing batch 510/559
# Processing batch 511/559
# Processing batch 512/559
# Processing batch 513/559
# Processing batch 514/559
# Processing batch 515/559
# Processing batch 516/559
# Processing batch 517/559
# Processing batch 518/559
# Processing batch 519/559
# Processing batch 520/559
# Processing batch 521/559
# Processing batch 522/559
# Processing batch 523/559
# Processing batch 524/559
# Processing batch 525/559
# Processing batch 526/559
# Processing batch 527/559
# Processing batch 528/559
# Processing batch 529/559
# Processing batch 530/559
# Processing batch 531/559
# Processing batch 532/559
# Processing batch 533/559
# Processing batch 534/559
# Processing batch 535/559
# Processing batch 536/559
# Processing batch 537/559
# Processing batch 538/559
# Processing batch 539/559
# Processing batch 540/559
# Processing batch 541/559
# Processing batch 542/559
# Processing batch 543/559
# Processing batch 544/559
# Processing batch 545/559
# Processing batch 546/559
# Processing batch 547/559
# Processing batch 548/559
# Processing batch 549/559
# Processing batch 550/559
# Processing batch 551/559
# Processing batch 552/559
# Processing batch 553/559
# Processing batch 554/559
# Processing batch 555/559
# Processing batch 556/559
# Processing batch 557/559
# Processing batch 558/559
# Processing batch 559/559
# Processing batch 1/208
# Processing batch 2/208
# Processing batch 3/208
# Processing batch 4/208
# Processing batch 5/208
# Processing batch 6/208
# Processing batch 7/208
# Processing batch 8/208
# Processing batch 9/208
# Processing batch 10/208
# Processing batch 11/208
# Processing batch 12/208
# Processing batch 13/208
# Processing batch 14/208
# Processing batch 15/208
# Processing batch 16/208
# Processing batch 17/208
# Processing batch 18/208
# Processing batch 19/208
# Processing batch 20/208
# Processing batch 21/208
# Processing batch 22/208
# Processing batch 23/208
# Processing batch 24/208
# Processing batch 25/208
# Processing batch 26/208
# Processing batch 27/208
# Processing batch 28/208
# Processing batch 29/208
# Processing batch 30/208
# Processing batch 31/208
# Processing batch 32/208
# Processing batch 33/208
# Processing batch 34/208
# Processing batch 35/208
# Processing batch 36/208
# Processing batch 37/208
# Processing batch 38/208
# Processing batch 39/208
# Processing batch 40/208
# Processing batch 41/208
# Processing batch 42/208
# Processing batch 43/208
# Processing batch 44/208
# Processing batch 45/208
# Processing batch 46/208
# Processing batch 47/208
# Processing batch 48/208
# Processing batch 49/208
# Processing batch 50/208
# Processing batch 51/208
# Processing batch 52/208
# Processing batch 53/208
# Processing batch 54/208
# Processing batch 55/208
# Processing batch 56/208
# Processing batch 57/208
# Processing batch 58/208
# Processing batch 59/208
# Processing batch 60/208
# Processing batch 61/208
# Processing batch 62/208
# Processing batch 63/208
# Processing batch 64/208
# Processing batch 65/208
# Processing batch 66/208
# Processing batch 67/208
# Processing batch 68/208
# Processing batch 69/208
# Processing batch 70/208
# Processing batch 71/208
# Processing batch 72/208
# Processing batch 73/208
# Processing batch 74/208
# Processing batch 75/208
# Processing batch 76/208
# Processing batch 77/208
# Processing batch 78/208
# Processing batch 79/208
# Processing batch 80/208
# Processing batch 81/208
# Processing batch 82/208
# Processing batch 83/208
# Processing batch 84/208
# Processing batch 85/208
# Processing batch 86/208
# Processing batch 87/208
# Processing batch 88/208
# Processing batch 89/208
# Processing batch 90/208
# Processing batch 91/208
# Processing batch 92/208
# Processing batch 93/208
# Processing batch 94/208
# Processing batch 95/208
# Processing batch 96/208
# Processing batch 97/208
# Processing batch 98/208
# Processing batch 99/208
# Processing batch 100/208
# Processing batch 101/208
# Processing batch 102/208
# Processing batch 103/208
# Processing batch 104/208
# Processing batch 105/208
# Processing batch 106/208
# Processing batch 107/208
# Processing batch 108/208
# Processing batch 109/208
# Processing batch 110/208
# Processing batch 111/208
# Processing batch 112/208
# Processing batch 113/208
# Processing batch 114/208
# Processing batch 115/208
# Processing batch 116/208
# Processing batch 117/208
# Processing batch 118/208
# Processing batch 119/208
# Processing batch 120/208
# Processing batch 121/208
# Processing batch 122/208
# Processing batch 123/208
# Processing batch 124/208
# Processing batch 125/208
# Processing batch 126/208
# Processing batch 127/208
# Processing batch 128/208
# Processing batch 129/208
# Processing batch 130/208
# Processing batch 131/208
# Processing batch 132/208
# Processing batch 133/208
# Processing batch 134/208
# Processing batch 135/208
# Processing batch 136/208
# Processing batch 137/208
# Processing batch 138/208
# Processing batch 139/208
# Processing batch 140/208
# Processing batch 141/208
# Processing batch 142/208
# Processing batch 143/208
# Processing batch 144/208
# Processing batch 145/208
# Processing batch 146/208
# Processing batch 147/208
# Processing batch 148/208
# Processing batch 149/208
# Processing batch 150/208
# Processing batch 151/208
# Processing batch 152/208
# Processing batch 153/208
# Processing batch 154/208
# Processing batch 155/208
# Processing batch 156/208
# Processing batch 157/208
# Processing batch 158/208
# Processing batch 159/208
# Processing batch 160/208
# Processing batch 161/208
# Processing batch 162/208
# Processing batch 163/208
# Processing batch 164/208
# Processing batch 165/208
# Processing batch 166/208
# Processing batch 167/208
# Processing batch 168/208
# Processing batch 169/208
# Processing batch 170/208
# Processing batch 171/208
# Processing batch 172/208
# Processing batch 173/208
# Processing batch 174/208
# Processing batch 175/208
# Processing batch 176/208
# Processing batch 177/208
# Processing batch 178/208
# Processing batch 179/208
# Processing batch 180/208
# Processing batch 181/208
# Processing batch 182/208
# Processing batch 183/208
# Processing batch 184/208
# Processing batch 185/208
# Processing batch 186/208
# Processing batch 187/208
# Processing batch 188/208
# Processing batch 189/208
# Processing batch 190/208
# Processing batch 191/208
# Processing batch 192/208
# Processing batch 193/208
# Processing batch 194/208
# Processing batch 195/208
# Processing batch 196/208
# Processing batch 197/208
# Processing batch 198/208
# Processing batch 199/208
# Processing batch 200/208
# Processing batch 201/208
# Processing batch 202/208
# Processing batch 203/208
# Processing batch 204/208
# Processing batch 205/208
# Processing batch 206/208
# Processing batch 207/208
# Processing batch 208/208
# Processing batch 1/21
# Processing batch 2/21
# Processing batch 3/21
# Processing batch 4/21
# Processing batch 5/21
# Processing batch 6/21
# Processing batch 7/21
# Processing batch 8/21
# Processing batch 9/21
# Processing batch 10/21
# Processing batch 11/21
# Processing batch 12/21
# Processing batch 13/21
# Processing batch 14/21
# Processing batch 15/21
# Processing batch 16/21
# Processing batch 17/21
# Processing batch 18/21
# Processing batch 19/21
# Processing batch 20/21
# Processing batch 21/21

# %%
train_df.reset_index(drop=True, inplace=True)
val_df.reset_index(drop=True, inplace=True)
test_df.reset_index(drop=True, inplace=True)

# %%
train_embedded_df=pd.concat([train_df,train_embedded],axis=1)
val_embedded_df=pd.concat([val_df,val_embedded],axis=1)
test_embedded_df=pd.concat([test_df,test_embedded],axis=1)

# %%
train_embedded_df.to_csv("/kaggle/working/train_embedded_df.csv",index=False)
val_embedded_df.to_csv("/kaggle/working/val_embedded_df.csv",index=False)
test_embedded_df.to_csv("/kaggle/working/test_embedded_df.csv",index=False)

# %%
save_directory = "./saved_model"

# Save model and tokenizer
model.save_pretrained(save_directory)
tokenizer.save_pretrained(save_directory)
# Out:
# ('./saved_model/tokenizer_config.json',
#  './saved_model/special_tokens_map.json',
#  './saved_model/vocab.txt',
#  './saved_model/added_tokens.json',
#  './saved_model/tokenizer.json')
